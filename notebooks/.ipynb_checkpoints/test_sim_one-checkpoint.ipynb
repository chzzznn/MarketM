# %%
import sys
sys.path.append('../src')  # to import from /src

from asset_classes import StockCard, BondCard, CommodityCard, CryptoCard
from order_book import OrderBook
from market_simulation import run_simulation_round
from portfolio import Portfolio

import matplotlib.pyplot as plt

# Step 1: Create assets
assets = [
    StockCard("TechCorp", base_price=100, volatility=5, sector="Technology"),
    StockCard("EcoPower", base_price=90, volatility=4, sector="Energy"),
    BondCard("GovBond 10Y", base_price=95, volatility=2, duration=10, yield_percent=1.5),
    CommodityCard("Gold Futures", base_price=85, volatility=3, reacts_to="Recession"),
    CryptoCard("BitNova", base_price=110, volatility=6)
]

# Step 2: Initialize order book and portfolios
orderbook = OrderBook()
portfolios = {
    "Player1": Portfolio("Player1", initial_cash=500),
    "Player2": Portfolio("Player2", initial_cash=500),
    "MarketMaker": Portfolio("MarketMaker", initial_cash=9999)
}

# Step 3: Track asset prices and portfolio values over time
price_history = {asset.name: [asset.current_price] for asset in assets}
portfolio_value_history = {pid: [pf.get_total_value({a.name: a.current_price for a in assets})] for pid, pf in portfolios.items()}

# Step 4: Simulate 10 market rounds
for round_num in range(10):
    print(f"\n📈 Round {round_num + 1}")

    # Run the simulation round
    run_simulation_round(assets, orderbook, portfolios)

    # Save price history
    for asset in assets:
        price_history[asset.name].append(asset.current_price)

    # Save portfolio values
    for pid, pf in portfolios.items():
        portfolio_value_history[pid].append(pf.get_total_value({a.name: a.current_price for a in assets}))

# Step 5: Plot asset price movements
plt.figure(figsize=(12, 5))
for name, history in price_history.items():
    plt.plot(history, label=name)
plt.title("Asset Prices Over Time")
plt.xlabel("Round")
plt.ylabel("Price ($)")
plt.legend()
plt.grid(True)
plt.show()

# Step 6: Plot portfolio values over time
plt.figure(figsize=(12, 5))
for pid, history in portfolio_value_history.items():
    plt.plot(history, label=pid)
plt.title("Portfolio Value Over Time")
plt.xlabel("Round")
plt.ylabel("Total Value ($)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 📈 Round 1
#
# 🔄 Simulating Market Round...
#
# 🌐 Market Event: Recession
# TechCorp [Bear] rolls 2.0, changes by -106.67
# EcoPower [Bull] rolls 4.0, changes by -230.40
# GovBond 10Y [Bear] rolls 4.0, changes by -81.07
# Gold Futures [Neutral] rolls 2.0, changes by -110.50
# BitNova [Bear] rolls 4.0, changes by -281.60
#
# 💰 Diversification Bonuses:
#
# 📊 Prices After Round:
# TechCorp: $1.00
# EcoPower: $1.00
# GovBond 10Y: $13.93
# Gold Futures: $1.00
# BitNova: $1.00
#
# 📈 Round 2
#
# 🔄 Simulating Market Round...
#
# 🌐 Market Event: None
# TechCorp [Bear] rolls 6.0, changes by 400.00
# EcoPower [Neutral] rolls 5.0, changes by 300.00
# GovBond 10Y [Bull] rolls 4.0, changes by -152.00
# Gold Futures [Neutral] rolls 4.0, changes by -170.00
# BitNova [Bull] rolls 5.0, changes by -660.00
#
# 💰 Diversification Bonuses:
#
# 📊 Prices After Round:
# TechCorp: $401.00
# EcoPower: $301.00
# GovBond 10Y: $1.00
# Gold Futures: $1.00
# BitNova: $1.00
#
# 📈 Round 3
#
# 🔄 Simulating Market Round...
#
# 🌐 Market Event: None
# TechCorp [Bear] rolls 4.0, changes by -266.67
# EcoPower [Neutral] rolls 6.0, changes by -360.00
# GovBond 10Y [Neutral] rolls 5.0, changes by 158.33
# Gold Futures [Neutral] rolls 4.0, changes by -170.00
# BitNova [Bear] rolls 6.0, changes by -528.00
#
# 💰 Diversification Bonuses:
#
# 📊 Prices After Round:
# TechCorp: $134.33
# EcoPower: $1.00
# GovBond 10Y: $159.33
# Gold Futures: $1.00
# BitNova: $1.00
#
# 📈 Round 4
#
# 🔄 Simulating Market Round...
#
# 🌐 Market Event: None
# TechCorp [Bear] rolls 6.0, changes by 400.00
# EcoPower [Bull] rolls 4.0, changes by 288.00
# GovBond 10Y [Neutral] rolls 4.0, changes by -126.67
# Gold Futures [Bear] rolls 4.0, changes by -136.00
# BitNova [Bear] rolls 6.0, changes by -528.00
#
# 💰 Diversification Bonuses:
#
# 📊 Prices After Round:
# TechCorp: $534.33
# EcoPower: $289.00
# GovBond 10Y: $32.67
# Gold Futures: $1.00
# BitNova: $1.00
#
# 📈 Round 5
#
# 🔄 Simulating Market Round...
#
# 🌐 Market Event: None
# TechCorp [Neutral] rolls 3.0, changes by 250.00
# EcoPower [Bear] rolls 5.0, changes by 240.00
# GovBond 10Y [Bull] rolls 6.0, changes by -228.00
# Gold Futures [Bull] rolls 1.0, changes by -51.00
# BitNova [Bull] rolls 3.0, changes by -396.00
#
# 💰 Diversification Bonuses:
#
# 📊 Prices After Round:
# TechCorp: $784.33
# EcoPower: $529.00
# GovBond 10Y: $1.00
# Gold Futures: $1.00
# BitNova: $1.00
#
# 📈 Round 6
#
# 🔄 Simulating Market Round...
#
# 🌐 Market Event: None
# TechCorp [Bull] rolls 6.0, changes by 600.00
# EcoPower [Neutral] rolls 6.0, changes by 360.00
# GovBond 10Y [Bear] rolls 5.0, changes by 126.67
# Gold Futures [Neutral] rolls 4.0, changes by 170.00
# BitNova [Bull] rolls 6.0, changes by -792.00
#
# 💰 Diversification Bonuses:
#
# 📊 Prices After Round:
# TechCorp: $1384.33
# EcoPower: $889.00
# GovBond 10Y: $127.67
# Gold Futures: $171.00
# BitNova: $1.00
#
# 📈 Round 7
#
# 🔄 Simulating Market Round...
#
# 🌐 Market Event: Inflation Spike
# TechCorp [Bear] rolls 6.0, changes by -360.00
# EcoPower [Bear] rolls 4.0, changes by -172.80
# GovBond 10Y [Bull] rolls 6.0, changes by -205.20
# Gold Futures [Neutral] rolls 4.0, changes by 212.50
# BitNova [Neutral] rolls 6.0, changes by 594.00
#
# 💰 Diversification Bonuses:
#
# 📊 Prices After Round:
# TechCorp: $1024.33
# EcoPower: $716.20
# GovBond 10Y: $1.00
# Gold Futures: $383.50
# BitNova: $595.00
#
# 📈 Round 8
#
# 🔄 Simulating Market Round...
#
# 🌐 Market Event: Inflation Spike
# TechCorp [Bull] rolls 6.0, changes by 540.00
# EcoPower [Neutral] rolls 5.0, changes by 270.00
# GovBond 10Y [Bull] rolls 5.0, changes by -171.00
# Gold Futures [Neutral] rolls 4.0, changes by -212.50
# BitNova [Bear] rolls 6.0, changes by 475.20
#
# 💰 Diversification Bonuses:
#
# 📊 Prices After Round:
# TechCorp: $1564.33
# EcoPower: $986.20
# GovBond 10Y: $1.00
# Gold Futures: $171.00
# BitNova: $1070.20
#
# 📈 Round 9
#
# 🔄 Simulating Market Round...
#
# 🌐 Market Event: None
# TechCorp [Neutral] rolls 6.0, changes by 500.00
# EcoPower [Bear] rolls 5.0, changes by -240.00
# GovBond 10Y [Bull] rolls 4.0, changes by -152.00
# Gold Futures [Bear] rolls 6.0, changes by -204.00
# BitNova [Bull] rolls 4.0, changes by 528.00
#
# 💰 Diversification Bonuses:
#
# 📊 Prices After Round:
# TechCorp: $2064.33
# EcoPower: $746.20
# GovBond 10Y: $1.00
# Gold Futures: $1.00
# BitNova: $1598.20
#
# 📈 Round 10
#
# 🔄 Simulating Market Round...
#
# 🌐 Market Event: None
# TechCorp [Bear] rolls 4.0, changes by -266.67
# EcoPower [Neutral] rolls 5.0, changes by -300.00
# GovBond 10Y [Bull] rolls 4.0, changes by 152.00
# Gold Futures [Neutral] rolls 5.0, changes by 212.50
# BitNova [Bear] rolls 2.0, changes by 176.00
#
# 💰 Diversification Bonuses:
#
# 📊 Prices After Round:
# TechCorp: $1797.67
# EcoPower: $446.20
# GovBond 10Y: $153.00
# Gold Futures: $213.50
# BitNova: $1774.20
