# %%
import sys
sys.path.append('../src')  # So we can import from /src

from asset_classes import Card, CardType
from market_simulation import run_simulation_round

# Step 1: Define your assets
assets = [
    Card("TechCorp", CardType.STOCK, 100, 5),
    Card("Gold Futures", CardType.COMMODITY, 80, 3),
    Card("GovBond 10Y", CardType.BOND, 90, 2)
]

# Step 2: Simulate a market round
print("Market Starting:")
for a in assets:
    print(a)

run_simulation_round(assets)
# Out:
# Market Starting:
# TechCorp ($100.00)
# Gold Futures ($80.00)
# GovBond 10Y ($90.00)
#
# 🔄 Simulating Market Round...
# TechCorp [Neutral] rolls 1, changes by 83.33
# Gold Futures [Bear] rolls 3, changes by -96.00
# GovBond 10Y [Bull] rolls 3, changes by -108.00
#
# 📊 Prices After Round:
# TechCorp ($183.33)
# Gold Futures ($1.00)
# GovBond 10Y ($1.00)

# %%
import matplotlib.pyplot as plt

prices = {asset.name: [asset.current_price] for asset in assets}
for _ in range(10):
    run_simulation_round(assets)
    for a in assets:
        prices[a.name].append(a.current_price)

# Plotting
for name, price_history in prices.items():
    plt.plot(price_history, label=name)
plt.legend()
plt.title("Asset Prices Over Time")
plt.xlabel("Round")
plt.ylabel("Price")
plt.show()
# Out:
# 🔄 Simulating Market Round...
# TechCorp [Bear] rolls 5, changes by -333.33
# Gold Futures [Bear] rolls 5, changes by 160.00
# GovBond 10Y [Bull] rolls 6, changes by -216.00
#
# 📊 Prices After Round:
# TechCorp ($1.00)
# Gold Futures ($161.00)
# GovBond 10Y ($1.00)
#
# 🔄 Simulating Market Round...
# TechCorp [Bull] rolls 3, changes by 300.00
# Gold Futures [Bull] rolls 6, changes by 288.00
# GovBond 10Y [Bull] rolls 5, changes by -180.00
#
# 📊 Prices After Round:
# TechCorp ($301.00)
# Gold Futures ($449.00)
# GovBond 10Y ($1.00)
#
# 🔄 Simulating Market Round...
# TechCorp [Neutral] rolls 2, changes by -166.67
# Gold Futures [Bear] rolls 6, changes by -192.00
# GovBond 10Y [Bear] rolls 4, changes by -96.00
#
# 📊 Prices After Round:
# TechCorp ($134.33)
# Gold Futures ($257.00)
# GovBond 10Y ($1.00)
#
# 🔄 Simulating Market Round...
# TechCorp [Bull] rolls 4, changes by -400.00
# Gold Futures [Neutral] rolls 1, changes by -40.00
# GovBond 10Y [Bear] rolls 4, changes by -96.00
#
# 📊 Prices After Round:
# TechCorp ($1.00)
# Gold Futures ($217.00)
# GovBond 10Y ($1.00)
#
# 🔄 Simulating Market Round...
# TechCorp [Bear] rolls 4, changes by 266.67
# Gold Futures [Neutral] rolls 3, changes by 120.00
# GovBond 10Y [Bear] rolls 4, changes by -96.00
#
# 📊 Prices After Round:
# TechCorp ($267.67)
# Gold Futures ($337.00)
# GovBond 10Y ($1.00)
#
# 🔄 Simulating Market Round...
# TechCorp [Bear] rolls 3, changes by -200.00
# Gold Futures [Bear] rolls 1, changes by 32.00
# GovBond 10Y [Bear] rolls 4, changes by -96.00
#
# 📊 Prices After Round:
# TechCorp ($67.67)
# Gold Futures ($369.00)
# GovBond 10Y ($1.00)
#
# 🔄 Simulating Market Round...
# TechCorp [Bear] rolls 5, changes by 333.33
# Gold Futures [Bull] rolls 1, changes by 48.00
# GovBond 10Y [Bear] rolls 5, changes by -120.00
#
# 📊 Prices After Round:
# TechCorp ($401.00)
# Gold Futures ($417.00)
# GovBond 10Y ($1.00)
#
# 🔄 Simulating Market Round...
# TechCorp [Bear] rolls 2, changes by -133.33
# Gold Futures [Bear] rolls 3, changes by -96.00
# GovBond 10Y [Neutral] rolls 2, changes by -60.00
#
# 📊 Prices After Round:
# TechCorp ($267.67)
# Gold Futures ($321.00)
# GovBond 10Y ($1.00)
#
# 🔄 Simulating Market Round...
# TechCorp [Bull] rolls 5, changes by -500.00
# Gold Futures [Bull] rolls 6, changes by -288.00
# GovBond 10Y [Bear] rolls 3, changes by -72.00
#
# 📊 Prices After Round:
# TechCorp ($1.00)
# Gold Futures ($33.00)
# GovBond 10Y ($1.00)
#
# 🔄 Simulating Market Round...
# TechCorp [Neutral] rolls 6, changes by 500.00
# Gold Futures [Neutral] rolls 6, changes by 240.00
# GovBond 10Y [Bear] rolls 1, changes by 24.00
#
# 📊 Prices After Round:
# TechCorp ($501.00)
# Gold Futures ($273.00)
# GovBond 10Y ($25.00)
